# %%
import pandas as pd
import numpy as np
import os
os.getcwd()
# Out:
# 'C:\\Users\\lakshit gupta'

# %%
tweets_donald = pd.read_csv(r"C:\Users\lakshit gupta\Downloads\hashtag_donaldtrump.csv\hashtag_donaldtrump.csv",
    engine='python',
    quoting=1,
    encoding='ISO-8859-1',  # or 'latin1'
    on_bad_lines='warn'     # Warn instead of skipping silently
)

# %%
tweets_donald
# Out:
#                  created_at                tweet_id  \
# 0       2020-10-15 00:00:01   1.316529221557252e+18
# 1       2020-10-15 00:00:01  1.3165292227484303e+18
# 2       2020-10-15 00:00:02   1.316529228091847e+18
# 3       2020-10-15 00:00:02   1.316529227471237e+18
# 4       2020-10-15 00:00:08  1.3165292523014513e+18
# ...                     ...                     ...
# 971082  2020-11-08 23:59:43  1.3255888434882765e+18
# 971083  2020-11-08 23:59:48  1.3255888660451942e+18
# 971084  2020-11-08 23:59:53  1.3255888855152271e+18
# 971085  2020-11-08 23:59:54  1.3255888929054024e+18
# 971086  2020-11-08 23:59:55  1.3255888944825344e+18
#
#                                                     tweet  likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0
# 1       Usa 2020, Trump contro Facebook e Twitter: cop...   26.0
# 2       #Trump: As a student I used to hear for years,...    2.0
# 3       2 hours since last tweet from #Trump! Maybe he...    0.0
# ...

# %%
tweets_biden = pd.read_csv(r"C:\Users\lakshit gupta\Downloads\hashtag_joebiden.csv\hashtag_joebiden.csv",
    engine='python',
    quoting=1,
    encoding='ISO-8859-1',  # or 'latin1'
    on_bad_lines='warn'     # Warn instead of skipping silently
)

# %%
tweets_biden
# Out:
#                  created_at                tweet_id  \
# 0       2020-10-15 00:00:01   1.316529221557252e+18
# 1       2020-10-15 00:00:18    1.31652929585929e+18
# 2       2020-10-15 00:00:20  1.3165293050069524e+18
# 3       2020-10-15 00:00:21  1.3165293080815575e+18
# 4       2020-10-15 00:00:22   1.316529312741253e+18
# ...                     ...                     ...
# 777068  2020-11-08 23:59:38  1.3255888248362353e+18
# 777069  2020-11-08 23:59:38   1.325588825654096e+18
# 777070  2020-11-08 23:59:41  1.3255888381237576e+18
# 777071  2020-11-08 23:59:52  1.3255888813460152e+18
# 777072  2020-11-08 23:59:58  1.3255889087264236e+18
#
#                                                     tweet likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...   0.0
# 1       #HunterBiden #HunterBidenEmails #JoeBiden #Joe...   0.0
# 2       @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...   0.0
# 3       @chrislongview Watching and setting dvr. Letâ...   0.0
# ...

# %%
tweets_biden.shape
# Out:
# (777073, 21)

# %%
tweets_donald.shape
# Out:
# (971087, 21)

# %%
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

df = tweets_donald.copy()
# Step 1: Drop duplicates and nulls
df.drop_duplicates(subset="tweet", inplace=True)
df.dropna(subset=["tweet"], inplace=True)

# Step 2: Clean tweet text
def clean_tweet(text):
    text = re.sub(r"http\S+|www.\S+", "", text)  # remove URLs
    text = re.sub(r"@\w+", "", text)  # remove mentions
    text = re.sub(r"#", "", text)  # remove hashtag symbol but keep text
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # remove special chars and numbers
    text = text.lower()  # convert to lowercase
    text = re.sub(r"\s+", " ", text).strip()  # remove extra spaces
    return text

df["cleaned_tweet"] = df["tweet"].astype(str).apply(clean_tweet)

# Step 3: Filter out very short tweets
df = df[df["cleaned_tweet"].apply(lambda x: len(x.split()) >= 5)]

df.dropna(subset=["country", "user_id"], inplace = True)
df["country"] = df["country"].replace('United States', 
    'United States of America')

# %%
filtered_tweets_donald = df.copy()
filtered_tweets_donald.shape
# Out:
# (404476, 22)

# %%
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

df0 = tweets_biden.copy()
# Step 1: Drop duplicates and nulls
df.drop_duplicates(subset="tweet", inplace=True)
df.dropna(subset=["tweet"], inplace=True)

# Step 2: Clean tweet text
def clean_tweet(text):
    text = re.sub(r"http\S+|www.\S+", "", text)  # remove URLs
    text = re.sub(r"@\w+", "", text)  # remove mentions
    text = re.sub(r"#", "", text)  # remove hashtag symbol but keep text
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # remove special chars and numbers
    text = text.lower()  # convert to lowercase
    text = re.sub(r"\s+", " ", text).strip()  # remove extra spaces
    return text

df0["cleaned_tweet"] = df0["tweet"].astype(str).apply(clean_tweet)

# Step 3: Filter out very short tweets
df0 = df0[df0["cleaned_tweet"].apply(lambda x: len(x.split()) >= 5)]

df0.dropna(subset=["country", "user_id"], inplace = True)
df0["country"] = df["country"].replace('United States', 
    'United States of America')

# %%
df0
# Out:
#                  created_at                tweet_id  \
# 0       2020-10-15 00:00:01   1.316529221557252e+18
# 2       2020-10-15 00:00:20  1.3165293050069524e+18
# 4       2020-10-15 00:00:22   1.316529312741253e+18
# 6       2020-10-15 00:00:25  1.3165293244182405e+18
# 11      2020-10-15 00:00:57  1.3165294600327987e+18
# ...                     ...                     ...
# 777062  2020-11-08 23:59:15   1.325588729424212e+18
# 777063  2020-11-08 23:59:16   1.325588732318265e+18
# 777066  2020-11-08 23:59:34   1.325588806679081e+18
# 777068  2020-11-08 23:59:38  1.3255888248362353e+18
# 777070  2020-11-08 23:59:41  1.3255888381237576e+18
#
#                                                     tweet likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...   0.0
# 2       @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...   0.0
# 4       #censorship #HunterBiden #Biden #BidenEmails #...   1.0
# 6       In 2020, #NYPost is being #censorship #CENSORE...   0.0
# ...

# %%
filtered_tweets_biden = df0.copy()
filtered_tweets_biden.shape
# Out:
# (319865, 22)

# %%
print('hello world i am kawai')
# Out:
# hello world i am kawai

# %%
filtered_tweets_biden.to_csv(r"C:\Users\lakshit gupta\Downloads\filtered_tweets_biden.csv", index=False)

# %%
filtered_tweets_donald.to_csv(r"C:\Users\lakshit gupta\Downloads\filtered_tweets_donald.csv", index=False)
